# %%
import sys
sys.path.append('../')

# %%
from utils.utils import Utils
from utils.preprocess import Preprocess

import pandas as pd
import numpy as np

# %%
# %%time
utils = Utils()
pre = Preprocess(mode="normalize")
# Out:
# CPU times: user 36.4 s, sys: 4.83 s, total: 41.2 s
# Wall time: 1min 22s

# %%
# %%time
data = utils.read_data("../dataset/test/messages_test_features_ready_for_WS_gold_emotion.csv")
data
# Out:
# CPU times: user 20.7 ms, sys: 22 µs, total: 20.7 ms
# Wall time: 94.3 ms
#               message_id        response_id  article_id gold_emotion  \
# 0    R_2qabL3aLPfRMyA1_1  R_2qabL3aLPfRMyA1          17      sadness
# 1    R_2qabL3aLPfRMyA1_2  R_2qabL3aLPfRMyA1         164          joy
# 2    R_2qabL3aLPfRMyA1_3  R_2qabL3aLPfRMyA1         196      neutral
# 3    R_2qabL3aLPfRMyA1_4  R_2qabL3aLPfRMyA1         259      neutral
# 4    R_2qabL3aLPfRMyA1_5  R_2qabL3aLPfRMyA1         361      neutral
# ..                   ...                ...         ...          ...
# 520  R_1gShpZuf35KXreS_1  R_1gShpZuf35KXreS          73          joy
# 521  R_1gShpZuf35KXreS_2  R_1gShpZuf35KXreS         164        anger
# 522  R_1gShpZuf35KXreS_3  R_1gShpZuf35KXreS         182      sadness
# 523  R_1gShpZuf35KXreS_4  R_1gShpZuf35KXreS         260      sadness
# 524  R_1gShpZuf35KXreS_5  R_1gShpZuf35KXreS         358        anger
#
# ...

# %%
post_no = 111
data.essay.values.tolist()[post_no]
# Out:
# "This isn't very surprising at all, is it? Another one of Putin's bodies. I like how it's just a thing that we expect to happen, and no one really cares very much except as a minor blip on the news. It's just expected, and the fact that people in our own government have an association with people who operate like this is largely going to be gotten away with. What do you think?"

# %%
# %%time
normalized_data = pre.normalize_corpus(data.copy(), column_name="essay")
normalized_data
# Out:
# CPU times: user 18.1 s, sys: 80.3 ms, total: 18.2 s
# Wall time: 19.9 s
#               message_id        response_id  article_id gold_emotion  \
# 0    R_2qabL3aLPfRMyA1_1  R_2qabL3aLPfRMyA1          17      sadness
# 1    R_2qabL3aLPfRMyA1_2  R_2qabL3aLPfRMyA1         164          joy
# 2    R_2qabL3aLPfRMyA1_3  R_2qabL3aLPfRMyA1         196      neutral
# 3    R_2qabL3aLPfRMyA1_4  R_2qabL3aLPfRMyA1         259      neutral
# 4    R_2qabL3aLPfRMyA1_5  R_2qabL3aLPfRMyA1         361      neutral
# ..                   ...                ...         ...          ...
# 520  R_1gShpZuf35KXreS_1  R_1gShpZuf35KXreS          73          joy
# 521  R_1gShpZuf35KXreS_2  R_1gShpZuf35KXreS         164        anger
# 522  R_1gShpZuf35KXreS_3  R_1gShpZuf35KXreS         182      sadness
# 523  R_1gShpZuf35KXreS_4  R_1gShpZuf35KXreS         260      sadness
# 524  R_1gShpZuf35KXreS_5  R_1gShpZuf35KXreS         358        anger
#
# ...

# %%
normalized_data.essay.values.tolist()[post_no]
# Out:
# "This is not very surprising at all , is it ? Another one of Putin 's bodies . I like how it is just a thing that we expect to happen , and no one really cares very much except as a minor blip on the news . it is just expected , and the fact that people in our own government have an association with people who operate like this is largely going to be gotten away with . What do you think ?"

# %%
normalized_data.to_csv("../dataset/test/test-empathy-distress-prediction-task-gold-new-text-normalization.csv", sep=",", index=False)

# %%
df = pd.read_csv("../dataset/test/test-empathy-distress-prediction-task-gold-new-text-normalization.csv")
df
# Out:
#               message_id        response_id  article_id gold_emotion  \
# 0    R_2qabL3aLPfRMyA1_1  R_2qabL3aLPfRMyA1          17      sadness
# 1    R_2qabL3aLPfRMyA1_2  R_2qabL3aLPfRMyA1         164          joy
# 2    R_2qabL3aLPfRMyA1_3  R_2qabL3aLPfRMyA1         196      neutral
# 3    R_2qabL3aLPfRMyA1_4  R_2qabL3aLPfRMyA1         259      neutral
# 4    R_2qabL3aLPfRMyA1_5  R_2qabL3aLPfRMyA1         361      neutral
# ..                   ...                ...         ...          ...
# 520  R_1gShpZuf35KXreS_1  R_1gShpZuf35KXreS          73          joy
# 521  R_1gShpZuf35KXreS_2  R_1gShpZuf35KXreS         164        anger
# 522  R_1gShpZuf35KXreS_3  R_1gShpZuf35KXreS         182      sadness
# 523  R_1gShpZuf35KXreS_4  R_1gShpZuf35KXreS         260      sadness
# 524  R_1gShpZuf35KXreS_5  R_1gShpZuf35KXreS         358        anger
#
#                                                  essay  gender  education  \
# ...
