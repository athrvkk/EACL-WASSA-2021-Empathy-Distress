# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv ('/home/raju/WASSA-2021-Shared-Task/dataset/track-1-essay-empathy-train.csv')

# %%
#histogram plots of all columns of the csv file
df.hist(bins=50,figsize=(30,30))
plt.show()

# %%
def groupeInfo(feature):
    '''Function to group a feature
    @parm feature (panda Series): feature of dataset to be grouped
    @return z: Grouped dataframe
    '''
    x=pd.DataFrame(feature)
    for col in x:
        z=x.groupby(pd.cut(x[col], np.arange(0,8,1))).count()
    return z

# %%
distressGroup =groupeInfo(df["distress"])
print(distressGroup)
empathyGroup =groupeInfo(df["empathy"])
print(empathyGroup)
# Out:
#           distress
# distress
# (0, 1]         239
# (1, 2]         260
# (2, 3]         225
# (3, 4]         288
# (4, 5]         312
# (5, 6]         311
# (6, 7]         225
#          empathy
# empathy
# (0, 1]       279
# (1, 2]       190
# (2, 3]       226
# (3, 4]       342
# (4, 5]       346
# (5, 6]       302
# (6, 7]       175

# %%
#don't know if this is useful
df["distress"].hist(by=df["distress"],bins=50,figsize=(30,30))
plt.show()

# %%
#further experiments
x=pd.DataFrame(df["income"])
z=x.groupby(pd.cut(x["income"], np.arange(0,200000,10000))).count()
print(z)
# Out:
#                   income
# income
# (0, 10000]            75
# (10000, 20000]       145
# (20000, 30000]       305
# (30000, 40000]       225
# (40000, 50000]       315
# (50000, 60000]       190
# (60000, 70000]       165
# (70000, 80000]       165
# (80000, 90000]        55
# (90000, 100000]       90
# (100000, 110000]      25
# (110000, 120000]      10
# (120000, 130000]      15
# (130000, 140000]      10
# (140000, 150000]      30
# (150000, 160000]      10
# (160000, 170000]       0
# (170000, 180000]       0
# (180000, 190000]       5

# %%
z.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb419f8ee50>]],
#       dtype=object)

# %%
x=pd.DataFrame(df["distress"])
z=x.groupby(pd.cut(x["distress"], np.arange(0,8,1))).count()
print(z)
z.hist()
x.hist()
# Out:
#           distress
# distress
# (0, 1]         239
# (1, 2]         260
# (2, 3]         225
# (3, 4]         288
# (4, 5]         312
# (5, 6]         311
# (6, 7]         225
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb41cc74f10>]],
#       dtype=object)

# %%
plt.scatter(df["gender"],df["empathy"])
