# %%
import pandas as pd

df = pd.read_csv (r'my_data.csv')
print (df)
# Out:
#                message_id        response_id  empathy  distress  empathy_bin  \
# 0     R_1hGrPtWM4SumG0U_1  R_1hGrPtWM4SumG0U    5.667     4.375            1
# 1     R_1hGrPtWM4SumG0U_2  R_1hGrPtWM4SumG0U    4.833     4.875            1
# 2     R_1hGrPtWM4SumG0U_3  R_1hGrPtWM4SumG0U    5.333     3.500            1
# 3     R_1hGrPtWM4SumG0U_4  R_1hGrPtWM4SumG0U    4.167     5.250            1
# 4     R_1hGrPtWM4SumG0U_5  R_1hGrPtWM4SumG0U    5.333     4.625            1
# ...                   ...                ...      ...       ...          ...
# 1855  R_DHy2Rcz9Hym8jgl_1  R_DHy2Rcz9Hym8jgl    1.000     1.000            0
# 1856  R_DHy2Rcz9Hym8jgl_2  R_DHy2Rcz9Hym8jgl    1.000     1.000            0
# 1857  R_DHy2Rcz9Hym8jgl_3  R_DHy2Rcz9Hym8jgl    1.000     1.000            0
# 1858  R_DHy2Rcz9Hym8jgl_4  R_DHy2Rcz9Hym8jgl    1.000     1.000            0
# 1859  R_DHy2Rcz9Hym8jgl_5  R_DHy2Rcz9Hym8jgl    1.000     1.000            0
#
#       distress_bin emotion_label  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['income'])
plt.xlabel('sr. no')
plt.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %%
fig, (ax, ax1) = plt.subplots(2)

ax.scatter(df['income'],df['empathy'])
ax.set(xlabel = 'income')
ax.set(ylabel = 'empathy')

ax1.scatter(df['income'],df['distress'])
ax1.set(xlabel = 'income')
ax1.set(ylabel = 'distress')
# Out:
# [Text(0, 0.5, 'distress')]

# %%
# Out:
# Text(0, 0.5, 'distress')

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['gender'],df['distress'])
ax.set(xlabel="gender",ylabel="distress")


ax1.scatter(df['gender'],df['empathy'])
ax1.set(xlabel="gender",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'gender')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['education'],df['distress'])
ax.set(xlabel="education",ylabel="distress")


ax1.scatter(df['education'],df['empathy'])
ax1.set(xlabel="education",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'education')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['age'],df['distress'])
ax.set(xlabel="age",ylabel="distress")


ax1.scatter(df['age'],df['empathy'])
ax.set(xlabel="age",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'age')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['race'],df['distress'])
ax.set(xlabel="race",ylabel="distress")


ax1.scatter(df['race'],df['empathy'])
ax1.set(xlabel="race",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'race')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['personality_conscientiousness'],df['distress'])
ax.set(xlabel="personality_conscientiousness",ylabel="distress")


ax1.scatter(df['personality_conscientiousness'],df['empathy'])
ax1.set(xlabel="personality_conscientiousness",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'personality_conscientiousness')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['personality_openess'],df['distress'])
ax.set(xlabel="personality_openess",ylabel="distress")


ax1.scatter(df['personality_openess'],df['empathy'])
ax1.set(xlabel="personality_openess",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'personality_openess')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['personality_extraversion'],df['distress'])
ax.set(xlabel="personality_extraversion",ylabel="distress")


ax1.scatter(df['personality_extraversion'],df['empathy'])
ax1.set(xlabel="personality_extraversion",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'personality_extraversion')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['personality_agreeableness'],df['distress'])
ax.set(xlabel="personality_agreeableness",ylabel="distress")


ax1.scatter(df['personality_agreeableness'],df['empathy'])
ax1.set(xlabel="personality_agreeableness",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'personality_agreeableness')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['personality_stability'],df['distress'])
ax.set(xlabel="personality_stability",ylabel="distress")


ax1.scatter(df['personality_stability'],df['empathy'])
ax1.set(xlabel="personality_stability",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'personality_stability')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['iri_perspective_taking'],df['distress'])
ax.set(xlabel="iri_perspective_taking",ylabel="distress")


ax1.scatter(df['iri_perspective_taking'],df['empathy'])
ax1.set(xlabel="iri_perspective_taking",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'iri_perspective_taking')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['iri_perspective_taking'],df['distress'])
ax.set(xlabel="iri_personal_distress",ylabel="distress")


ax1.scatter(df['iri_personal_distress'],df['empathy'])
ax1.set(xlabel="iri_personal_distress",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'iri_personal_distress')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['iri_fantasy'],df['distress'])
ax.set(xlabel="iri_fantasy",ylabel="distress")


ax1.scatter(df['iri_fantasy'],df['empathy'])
ax1.set(xlabel="iri_fantasy",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'iri_fantasy')]

# %%
fig, (ax, ax1) = plt.subplots(2)
ax.scatter(df['iri_empathatic_concern'],df['distress'])
ax.set(xlabel="iri_empathatic_concern",ylabel="distress")


ax1.scatter(df['iri_empathatic_concern'],df['empathy'])
ax1.set(xlabel="iri_empathatic_concern",ylabel="empathy")
# Out:
# [Text(0, 0.5, 'empathy'), Text(0.5, 0, 'iri_empathatic_concern')]

# %%
import numpy as np
import scipy.stats

# %%
print("Pearson income-empathy", scipy.stats.pearsonr(df['income'],df['empathy'])[0])    # Pearson's r
print("Spearman income-empathy", scipy.stats.spearmanr(df['income'],df['empathy'])[0])    # Spearman's rho
print("Kendall income-empathy", scipy.stats.kendalltau(df['income'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson income-empathy_bin", scipy.stats.pearsonr(df['income'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman income-empathy_bin", scipy.stats.spearmanr(df['income'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall income-empathy_bin", scipy.stats.kendalltau(df['income'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson income-distress", scipy.stats.pearsonr(df['income'],df['distress'])[0])    # Pearson's r
print("Spearman income-distress", scipy.stats.spearmanr(df['income'],df['distress'])[0])    # Spearman's rho
print("Kendall income-distress", scipy.stats.kendalltau(df['income'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson income-distress_bin", scipy.stats.pearsonr(df['income'],df['distress_bin'])[0])    # Pearson's r
print("Spearman income-distress_bin", scipy.stats.spearmanr(df['income'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall income-distress_bin", scipy.stats.kendalltau(df['income'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson income-empathy 0.03984276281366887
# Spearman income-empathy 0.08133348876239947
# Kendall income-empathy 0.05596897483483779
#
#
# Pearson income-empathy_bin 0.03718036700782649
# Spearman income-empathy_bin 0.09923494159869783
# Kendall income-empathy_bin 0.08198524632063361
#
#
# Pearson income-distress 0.04144073369094581
# Spearman income-distress 0.06999888415767472
# Kendall income-distress 0.048739373559533596
#
#
# Pearson income-distress_bin 0.05286378093860395
# Spearman income-distress_bin 0.07489066191225982
# Kendall income-distress_bin 0.06187265558961628

# %%
print("Pearson age-empathy", scipy.stats.pearsonr(df['age'],df['empathy'])[0])    # Pearson's r
print("Spearman age-empathy", scipy.stats.spearmanr(df['age'],df['empathy'])[0])    # Spearman's rho
print("Kendall age-empathy", scipy.stats.kendalltau(df['age'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson age-empathy_bin", scipy.stats.pearsonr(df['age'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman age-empathy_bin", scipy.stats.spearmanr(df['age'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall age-empathy_bin", scipy.stats.kendalltau(df['age'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson age-distress", scipy.stats.pearsonr(df['age'],df['distress'])[0])    # Pearson's r
print("Spearman age-distress", scipy.stats.spearmanr(df['age'],df['distress'])[0])    # Spearman's rho
print("Kendall age-distress", scipy.stats.kendalltau(df['age'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson age-distress_bin", scipy.stats.pearsonr(df['age'],df['distress_bin'])[0])    # Pearson's r
print("Spearman age-distress_bin", scipy.stats.spearmanr(df['age'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall age-distress_bin", scipy.stats.kendalltau(df['age'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson age-empathy 0.020448524640274565
# Spearman age-empathy -0.00690402180296706
# Kendall age-empathy -0.004143860751188369
#
#
# Pearson age-empathy_bin 0.03359961085309586
# Spearman age-empathy_bin 0.010825696789988494
# Kendall age-empathy_bin 0.009004353016089432
#
#
# Pearson age-distress -0.0707016730350584
# Spearman age-distress -0.09582817191267971
# Kendall age-distress -0.06381381803338047
#
#
# Pearson age-distress_bin -0.04864981549021823
# Spearman age-distress_bin -0.07829522652918709
# Kendall age-distress_bin -0.06512263116360939

# %%
print("Pearson gender-empathy", scipy.stats.pearsonr(df['gender'],df['empathy'])[0])    # Pearson's r
print("Spearman gender-empathy", scipy.stats.spearmanr(df['gender'],df['empathy'])[0])    # Spearman's rho
print("Kendall gender-empathy", scipy.stats.kendalltau(df['gender'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson gender-empathy_bin", scipy.stats.pearsonr(df['gender'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman gender-empathy_bin", scipy.stats.spearmanr(df['gender'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall gender-empathy_bin", scipy.stats.kendalltau(df['gender'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson gender-distress", scipy.stats.pearsonr(df['gender'],df['distress'])[0])    # Pearson's r
print("Spearman gender-distress", scipy.stats.spearmanr(df['gender'],df['distress'])[0])    # Spearman's rho
print("Kendall gender-distress", scipy.stats.kendalltau(df['gender'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson gender-distress_bin", scipy.stats.pearsonr(df['gender'],df['distress_bin'])[0])    # Pearson's r
print("Spearman gender-distress_bin", scipy.stats.spearmanr(df['gender'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall gender-distress_bin", scipy.stats.kendalltau(df['gender'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson gender-empathy -0.00766390979234334
# Spearman gender-empathy 0.007057702916261869
# Kendall gender-empathy 0.005968614040558102
#
#
# Pearson gender-empathy_bin -0.004269842791065719
# Spearman gender-empathy_bin 0.0002427708519316701
# Kendall gender-empathy_bin 0.00024213127857561573
#
#
# Pearson gender-distress 0.024215228727832744
# Spearman gender-distress 0.043176533818861364
# Kendall gender-distress 0.03576802355630981
#
#
# Pearson gender-distress_bin 0.002104502617141065
# Spearman gender-distress_bin 0.007030538413388405
# Kendall gender-distress_bin 0.007012016646824825

# %%
print("Pearson education-empathy", scipy.stats.pearsonr(df['education'],df['empathy'])[0])    # Pearson's r
print("Spearman education-empathy", scipy.stats.spearmanr(df['education'],df['empathy'])[0])    # Spearman's rho
print("Kendall education-empathy", scipy.stats.kendalltau(df['education'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson education-empathy_bin", scipy.stats.pearsonr(df['education'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman education-empathy_bin", scipy.stats.spearmanr(df['education'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall education-empathy_bin", scipy.stats.kendalltau(df['education'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson education-distress", scipy.stats.pearsonr(df['education'],df['distress'])[0])    # Pearson's r
print("Spearman education-distress", scipy.stats.spearmanr(df['education'],df['distress'])[0])    # Spearman's rho
print("Kendall education-distress", scipy.stats.kendalltau(df['education'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson education-distress_bin", scipy.stats.pearsonr(df['education'],df['distress_bin'])[0])    # Pearson's r
print("Spearman education-distress_bin", scipy.stats.spearmanr(df['education'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall education-distress_bin", scipy.stats.kendalltau(df['education'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson education-empathy 0.0310737271540795
# Spearman education-empathy 0.04259065531826194
# Kendall education-empathy 0.033341602810674414
#
#
# Pearson education-empathy_bin 0.04193856559121795
# Spearman education-empathy_bin 0.04282649826145236
# Kendall education-empathy_bin 0.0391242880316385
#
#
# Pearson education-distress 0.01080665773828495
# Spearman education-distress 0.01598152049034806
# Kendall education-distress 0.012336202886169925
#
#
# Pearson education-distress_bin 0.02910828509665166
# Spearman education-distress_bin 0.02873092802272846
# Kendall education-distress_bin 0.026247233582234557

# %%
print("Pearson race-empathy", scipy.stats.pearsonr(df['race'],df['empathy'])[0])    # Pearson's r
print("Spearman race-empathy", scipy.stats.spearmanr(df['race'],df['empathy'])[0])    # Spearman's rho
print("Kendall race-empathy", scipy.stats.kendalltau(df['race'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson race-empathy_bin", scipy.stats.pearsonr(df['race'],df['empathy'])[0])    # Pearson's r
print("Spearman race-empathy_bin", scipy.stats.spearmanr(df['race'],df['empathy'])[0])    # Spearman's rho
print("Kendall race-empathy_bin", scipy.stats.kendalltau(df['race'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson race-distress", scipy.stats.pearsonr(df['race'],df['distress'])[0])    # Pearson's r
print("Spearman race-distress", scipy.stats.spearmanr(df['race'],df['distress'])[0])    # Spearman's rho
print("Kendall race-distress", scipy.stats.kendalltau(df['race'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson race-distress_bin", scipy.stats.pearsonr(df['race'],df['distress_bin'])[0])    # Pearson's r
print("Spearman race-distress_bin", scipy.stats.spearmanr(df['race'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall race-distress_bin", scipy.stats.kendalltau(df['race'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson race-empathy -0.03845734281722216
# Spearman race-empathy -0.02130017353541069
# Kendall race-empathy -0.01725224752854908
#
#
# Pearson race-empathy_bin -0.03845734281722216
# Spearman race-empathy_bin -0.02130017353541069
# Kendall race-empathy_bin -0.01725224752854908
#
#
# Pearson race-distress -0.00042389871032061854
# Spearman race-distress 0.0009760397220365137
# Kendall race-distress 0.0002862337626647783
#
#
# Pearson race-distress_bin -0.017706633403253097
# Spearman race-distress_bin -0.0017742248639128618
# Kendall race-distress_bin -0.001698810572242789

# %%
print("Pearson personality_openess-empathy", scipy.stats.pearsonr(df['personality_openess'],df['empathy'])[0])    # Pearson's r
print("Spearman personality_openess-empathy", scipy.stats.spearmanr(df['personality_openess'],df['empathy'])[0])    # Spearman's rho
print("Kendall personality_openess-empathy", scipy.stats.kendalltau(df['personality_openess'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson personality_openess-empathy_bin", scipy.stats.pearsonr(df['personality_openess'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman personality_openess-empathy_bin", scipy.stats.spearmanr(df['personality_openess'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall personality_openess-empathy_bin", scipy.stats.kendalltau(df['personality_openess'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson personality_openess-distress", scipy.stats.pearsonr(df['personality_openess'],df['distress'])[0])    # Pearson's r
print("Spearman personality_openess-distress", scipy.stats.spearmanr(df['personality_openess'],df['distress'])[0])    # Spearman's rho
print("Kendall personality_openess-distress", scipy.stats.kendalltau(df['personality_openess'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson personality_openess-distress_bin", scipy.stats.pearsonr(df['personality_openess'],df['distress_bin'])[0])    # Pearson's r
print("Spearman personality_openess-distress_bin", scipy.stats.spearmanr(df['personality_openess'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall personality_openess-distress_bin", scipy.stats.kendalltau(df['personality_openess'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson personality_openess-empathy 0.11377269271127466
# Spearman personality_openess-empathy 0.10372058758655206
# Kendall personality_openess-empathy 0.07561545245567038
#
#
# Pearson personality_openess-empathy_bin 0.08255703650859547
# Spearman personality_openess-empathy_bin 0.08223029526512904
# Kendall personality_openess-empathy_bin 0.07082042623159687
#
#
# Pearson personality_openess-distress 0.014207526470026806
# Spearman personality_openess-distress 0.009869688165995299
# Kendall personality_openess-distress 0.006202817186974292
#
#
# Pearson personality_openess-distress_bin -0.0023540431162822756
# Spearman personality_openess-distress_bin -0.0025879912683309174
# Kendall personality_openess-distress_bin -0.002228894400973533

# %%
print("Pearson personality_stability-empathy", scipy.stats.pearsonr(df['personality_stability'],df['empathy'])[0])    # Pearson's r
print("Spearman personality_stability-empathy", scipy.stats.spearmanr(df['personality_stability'],df['empathy'])[0])    # Spearman's rho
print("Kendall personality_stability-empathy", scipy.stats.kendalltau(df['personality_stability'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson personality_stability-empathy_bin", scipy.stats.pearsonr(df['personality_stability'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman personality_stability-empathy_bin", scipy.stats.spearmanr(df['personality_stability'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall personality_stability-empathy_bin", scipy.stats.kendalltau(df['personality_stability'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson personality_stability-distress_bin", scipy.stats.pearsonr(df['personality_stability'],df['distress_bin'])[0])    # Pearson's r
print("Spearman personality_stability-distress_bin", scipy.stats.spearmanr(df['personality_stability'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall personality_stability-distress_bin", scipy.stats.kendalltau(df['personality_stability'],df['distress_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson personality_stability-distress", scipy.stats.pearsonr(df['personality_stability'],df['distress'])[0])    # Pearson's r
print("Spearman personality_stability-distress", scipy.stats.spearmanr(df['personality_stability'],df['distress'])[0])    # Spearman's rho
print("Kendall personality_stability-distress", scipy.stats.kendalltau(df['personality_stability'],df['distress'])[0])   # Kendall's tau
# Out:
# Pearson personality_stability-empathy 0.10378868962286633
# Spearman personality_stability-empathy 0.0853713922036921
# Kendall personality_stability-empathy 0.06435174248890635
#
#
# Pearson personality_stability-empathy_bin 0.08889433128579083
# Spearman personality_stability-empathy_bin 0.07439791452239239
# Kendall personality_stability-empathy_bin 0.06379617334504652
#
#
# Pearson personality_stability-distress_bin -0.06532951191037009
# Spearman personality_stability-distress_bin -0.0811517116225947
# Kendall personality_stability-distress_bin -0.06958755087636291
#
#
# Pearson personality_stability-distress -0.08377874554554807
# Spearman personality_stability-distress -0.09730051653937644
# Kendall personality_stability-distress -0.06856151504887627

# %%
print("Pearson iri_perspective_taking-empathy", scipy.stats.pearsonr(df['iri_perspective_taking'],df['empathy'])[0])    # Pearson's r
print("Spearman iri_perspective_taking-empathy", scipy.stats.spearmanr(df['iri_perspective_taking'],df['empathy'])[0])    # Spearman's rho
print("Kendall iri_perspective_taking-empathy", scipy.stats.kendalltau(df['iri_perspective_taking'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_perspective_taking-empathy_bin", scipy.stats.pearsonr(df['iri_perspective_taking'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman iri_perspective_taking-empathy_bin", scipy.stats.spearmanr(df['iri_perspective_taking'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall iri_perspective_taking-empathy_bin", scipy.stats.kendalltau(df['iri_perspective_taking'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_perspective_taking-distress", scipy.stats.pearsonr(df['iri_perspective_taking'],df['distress'])[0])    # Pearson's r
print("Spearman iri_perspective_taking-distress", scipy.stats.spearmanr(df['iri_perspective_taking'],df['distress'])[0])    # Spearman's rho
print("Kendall iri_perspective_taking-distress", scipy.stats.kendalltau(df['iri_perspective_taking'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_perspective_taking-distress_bin", scipy.stats.pearsonr(df['iri_perspective_taking'],df['distress_bin'])[0])    # Pearson's r
print("Spearman iri_perspective_taking-distress_bin", scipy.stats.spearmanr(df['iri_perspective_taking'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall iri_perspective_taking-distress_bin", scipy.stats.kendalltau(df['iri_perspective_taking'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson iri_perspective_taking-empathy 0.22856663040279532
# Spearman iri_perspective_taking-empathy 0.2090253818844349
# Kendall iri_perspective_taking-empathy 0.1505995415796975
#
#
# Pearson iri_perspective_taking-empathy_bin 0.2039726166352176
# Spearman iri_perspective_taking-empathy_bin 0.18465158723473124
# Kendall iri_perspective_taking-empathy_bin 0.15491818996847434
#
#
# Pearson iri_perspective_taking-distress 0.12652424670336937
# Spearman iri_perspective_taking-distress 0.10870882695025362
# Kendall iri_perspective_taking-distress 0.07823178478531168
#
#
# Pearson iri_perspective_taking-distress_bin 0.09224271188991356
# Spearman iri_perspective_taking-distress_bin 0.07457235668229169
# Kendall iri_perspective_taking-distress_bin 0.06256439325494817

# %%
print("Pearson iri_personal_distress-empathy", scipy.stats.pearsonr(df['iri_personal_distress'],df['empathy'])[0])    # Pearson's r
print("Spearman iri_personal_distress-empathy", scipy.stats.spearmanr(df['iri_personal_distress'],df['empathy'])[0])    # Spearman's rho
print("Kendall iri_personal_distress-empathy", scipy.stats.kendalltau(df['iri_personal_distress'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_personal_distress-empathy_bin", scipy.stats.pearsonr(df['iri_personal_distress'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman iri_personal_distress-empathy_bin", scipy.stats.spearmanr(df['iri_personal_distress'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall iri_personal_distress-empathy_bin", scipy.stats.kendalltau(df['iri_personal_distress'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_personal_distress-distress", scipy.stats.pearsonr(df['iri_personal_distress'],df['distress'])[0])    # Pearson's r
print("Spearman iri_personal_distress-distress", scipy.stats.spearmanr(df['iri_personal_distress'],df['distress'])[0])    # Spearman's rho
print("Kendall iri_personal_distress-distress", scipy.stats.kendalltau(df['iri_personal_distress'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_personal_distress-distress_bin", scipy.stats.pearsonr(df['iri_personal_distress'],df['distress_bin'])[0])    # Pearson's r
print("Spearman iri_personal_distress-distress_bin", scipy.stats.spearmanr(df['iri_personal_distress'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall iri_personal_distress-distress_bin", scipy.stats.kendalltau(df['iri_personal_distress'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson iri_personal_distress-empathy 0.0058061155491775564
# Spearman iri_personal_distress-empathy 0.010634704222322782
# Kendall iri_personal_distress-empathy 0.008153605237578434
#
#
# Pearson iri_personal_distress-empathy_bin -0.007286066871853422
# Spearman iri_personal_distress-empathy_bin -0.0046270587145914545
# Kendall iri_personal_distress-empathy_bin -0.00386337077585004
#
#
# Pearson iri_personal_distress-distress 0.18952486622501463
# Spearman iri_personal_distress-distress 0.1886517637849146
# Kendall iri_personal_distress-distress 0.1344337698373579
#
#
# Pearson iri_personal_distress-distress_bin 0.15533410278083734
# Spearman iri_personal_distress-distress_bin 0.15722866387250148
# Kendall iri_personal_distress-distress_bin 0.13127834821188444

# %%
print("Pearson iri_fantasy-empathy", scipy.stats.pearsonr(df['iri_fantasy'],df['empathy'])[0])    # Pearson's r
print("Spearman iri_fantasy-empathy", scipy.stats.spearmanr(df['iri_fantasy'],df['empathy'])[0])    # Spearman's rho
print("Kendall iri_fantasy-empathy", scipy.stats.kendalltau(df['iri_fantasy'],df['empathy'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_fantasy-empathy_bin", scipy.stats.pearsonr(df['iri_fantasy'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman iri_fantasy-empathy_bin", scipy.stats.spearmanr(df['iri_fantasy'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall iri_fantasy-empathy_bin", scipy.stats.kendalltau(df['iri_fantasy'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_fantasy-distress", scipy.stats.pearsonr(df['iri_fantasy'],df['distress'])[0])    # Pearson's r
print("Spearman iri_fantasy-distress", scipy.stats.spearmanr(df['iri_fantasy'],df['distress'])[0])    # Spearman's rho
print("Kendall iri_fantasy-distress", scipy.stats.kendalltau(df['iri_fantasy'],df['distress'])[0])   # Kendall's tau
print("\n")
print("Pearson iri_fantasy-distress_bin", scipy.stats.pearsonr(df['iri_fantasy'],df['distress_bin'])[0])    # Pearson's r
print("Spearman iri_fantasy-distress_bin", scipy.stats.spearmanr(df['iri_fantasy'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall iri_fantasy-distress_bin", scipy.stats.kendalltau(df['iri_fantasy'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson iri_fantasy-empathy 0.16171192259347203
# Spearman iri_fantasy-empathy 0.14155677649838053
# Kendall iri_fantasy-empathy 0.104694738617934
#
#
# Pearson iri_fantasy-empathy_bin 0.1314313802314151
# Spearman iri_fantasy-empathy_bin 0.11806296535392986
# Kendall iri_fantasy-empathy_bin 0.09886150701359765
#
#
# Pearson iri_fantasy-distress 0.12054128375079237
# Spearman iri_fantasy-distress 0.09586447394970166
# Kendall iri_fantasy-distress 0.06822953751135107
#
#
# Pearson iri_fantasy-distress_bin 0.05960993280812878
# Spearman iri_fantasy-distress_bin 0.04065660491628783
# Kendall iri_fantasy-distress_bin 0.03404431880930109

# %%
print("Pearson iri_empathatic_concern-empathy", scipy.stats.pearsonr(df['iri_empathatic_concern'],df['empathy'])[0])    # Pearson's r
print("Spearman iri_empathatic_concern-empathy", scipy.stats.spearmanr(df['iri_empathatic_concern'],df['empathy'])[0])    # Spearman's rho
print("Kendall iri_empathatic_concern-empathy", scipy.stats.kendalltau(df['iri_empathatic_concern'],df['empathy'])[0])   # Kendall's tau
print("\n")

print("Pearson iri_empathatic_concern-empathy_bin", scipy.stats.pearsonr(df['iri_empathatic_concern'],df['empathy_bin'])[0])    # Pearson's r
print("Spearman iri_empathatic_concern-empathy-bin", scipy.stats.spearmanr(df['iri_empathatic_concern'],df['empathy_bin'])[0])    # Spearman's rho
print("Kendall iri_empathatic_concern-empathy_bin", scipy.stats.kendalltau(df['iri_empathatic_concern'],df['empathy_bin'])[0])   # Kendall's tau
print("\n")

print("Pearson iri_empathatic_concern-distress", scipy.stats.pearsonr(df['iri_empathatic_concern'],df['distress'])[0])    # Pearson's r
print("Spearman iri_empathatic_concern-distress", scipy.stats.spearmanr(df['iri_empathatic_concern'],df['distress'])[0])    # Spearman's rho
print("Kendall iri_empathatic_concern-distress", scipy.stats.kendalltau(df['iri_empathatic_concern'],df['distress'])[0])   # Kendall's tau
print("\n")

print("Pearson iri_empathatic_concern-distress_bin", scipy.stats.pearsonr(df['iri_empathatic_concern'],df['distress_bin'])[0])    # Pearson's r
print("Spearman iri_empathatic_concern-distress_bin", scipy.stats.spearmanr(df['iri_empathatic_concern'],df['distress_bin'])[0])    # Spearman's rho
print("Kendall iri_empathatic_concern-distress_bin", scipy.stats.kendalltau(df['iri_empathatic_concern'],df['distress_bin'])[0])   # Kendall's tau
# Out:
# Pearson iri_empathatic_concern-empathy 0.29936333439833496
# Spearman iri_empathatic_concern-empathy 0.27641371174500123
# Kendall iri_empathatic_concern-empathy 0.20148491253259068
#
#
# Pearson iri_empathatic_concern-empathy_bin 0.23581734392522175
# Spearman iri_empathatic_concern-empathy-bin 0.22068761341538246
# Kendall iri_empathatic_concern-empathy_bin 0.18486088918505925
#
#
# Pearson iri_empathatic_concern-distress 0.19864478258616808
# Spearman iri_empathatic_concern-distress 0.1699855136213398
# Kendall iri_empathatic_concern-distress 0.12245104409461165
#
#
# Pearson iri_empathatic_concern-distress_bin 0.13034943213966776
# Spearman iri_empathatic_concern-distress_bin 0.10625512595531478
# Kendall iri_empathatic_concern-distress_bin 0.08900552577728331

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.metrics import mean_absolute_error
 
# feature selection
def select_features(X_train, y_train, X_test):
    # configure to select 1a subset of features
    fs = SelectKBest(score_func=f_regression, k=10)
    # learn relationship from training data
    fs.fit(X_train, y_train)
    xp = fs.get_params(deep=True)
    print(xp)
    # transform train input data
    X_train_fs = fs.transform(X_train)
    # transform test input data
    X_test_fs = fs.transform(X_test)
    return X_train_fs, X_test_fs, fs

# %%
x = df[df.columns[8:]]

# %%
y = df['empathy']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=1)

# %%
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
# Out:
# {'k': 10, 'score_func': <function f_regression at 0x0000027EC15823A8>}

# %%
print(X_train_fs[:5])
print(X_train[:5])
# Out:
# [[3.000e+00 6.000e+04 3.500e+00 4.500e+00 3.500e+00 4.000e+00 3.500e+00
#   2.571e+00 3.143e+00 3.000e+00]
#  [1.000e+00 1.600e+04 7.000e+00 6.500e+00 3.500e+00 6.500e+00 6.500e+00
#   3.714e+00 2.857e+00 3.714e+00]
#  [1.000e+00 3.900e+04 4.000e+00 6.000e+00 4.000e+00 4.000e+00 5.500e+00
#   4.143e+00 4.286e+00 3.714e+00]
#  [3.000e+00 2.500e+04 6.500e+00 4.000e+00 1.000e+00 4.500e+00 6.000e+00
#   4.143e+00 3.571e+00 4.286e+00]
#  [1.000e+00 8.600e+04 7.000e+00 7.000e+00 7.000e+00 7.000e+00 5.500e+00
#   4.429e+00 2.571e+00 4.143e+00]]
#       gender  education  race  age  income  personality_conscientiousness  \
# 308        1          4     3   30   60000                            3.5
# 632        2          5     1   61   16000                            7.0
# 764        1          6     1   58   39000                            4.0
# 730        2          6     3   30   25000                            6.5
# ...

# %%
model = Li()
model.fit(X_train_fs, y_train)
# evaluate the model
yhat = model.predict(X_test_fs)

# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 1.450

# %%
yhat[0]
# Out:
# 4.182583518108716
